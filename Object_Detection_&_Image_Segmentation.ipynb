# %% [markdown]
# <a href="https://colab.research.google.com/github/muneer-ahmad10/Computer-Vision-CV-/blob/main/Object_Detection_%26_Image_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Classification**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Detection**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
